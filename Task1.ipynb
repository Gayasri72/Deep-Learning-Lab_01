# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import seaborn as sns

# %% [markdown]
# Q1:

# %%
exp_array = np.random.exponential(scale=1.0, size=(4, 4))
print("4x4 Exponential Distribution Array:")
print(exp_array)
# Out:
# 4x4 Exponential Distribution Array:
# [[0.32308848 1.36281607 2.96578891 0.47757918]
#  [0.29221001 0.03394671 1.0088461  0.32873291]
#  [0.05116428 0.60471366 0.32404137 6.34508531]
#  [2.16611982 0.70394805 0.98104864 2.37446674]]

# %% [markdown]
# Q2:

# %%
exp_data = np.random.exponential(scale=1.0, size=(100000,))
uniform_data = np.random.rand(100000)
normal_data = np.random.normal(loc=0.0, scale=1.0, size=100000)

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.hist(exp_data, density=True, bins=100, histtype="step", label="Exponential", color="red")
plt.hist(uniform_data, density=True, bins=100, histtype="step", label="Uniform", color="green")
plt.hist(normal_data, density=True, bins=100, histtype="step", label="Normal", color="blue")
plt.title("Comparison of Random Distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.legend(loc="upper right")
plt.grid(True)
plt.show()

# %% [markdown]
# Q3:

# %%
# Meshgrid
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

# %%
# Plot
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_title('3D Plot of Z = X² + Y²')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %% [markdown]
# Q4:

# %%
#Load dataset
# !wget -q https://elitedatascience.com/wp-content/uploads/2022/07/Pokemon.csv
# Read dataset
df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')

# %%
#selecting mentioned features
num_df = df[["HP","Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]]

# %%
# Correlations
pearson_corr = num_df.corr(method="pearson")
spearman_corr = num_df.corr(method="spearman")

# %%
# Heatmap with values
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
sns.heatmap(pearson_corr, annot=True, cmap="coolwarm")
plt.title("Pearson Correlation")

plt.subplot(1, 2, 2)
sns.heatmap(spearman_corr, annot=True, cmap="coolwarm")
plt.title("Spearman Correlation")
plt.tight_layout()
plt.show()
